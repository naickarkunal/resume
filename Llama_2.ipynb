# %% [markdown]
# <a href="https://colab.research.google.com/github/naickarkunal/resume/blob/main/Llama_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install accelerate
# !pip install protobuf
# !pip install sentencepiece
# !pip install torch
# !pip install git+https://github.com/huggingface/transformers
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-_xyt3xs4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-_xyt3xs4
#   Resolved https://github.com/huggingface/transformers to commit 425ba56cdfef13841b6949a15a5ec575acc19fb5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.39.0.dev0-py3-none-any.whl size=8776094 sha256=5777ef01cb40a685c6f589cb4e6212ac8ec5ab16848153810d8551cfbcfb29e4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kuln85g_/wheels/c0/14/d6/6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer

# %%
from huggingface_hub import login
login()

# %%
if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-60e82671aeba> in <cell line: 1>()
# ----> 1 if torch.cuda.is_available():
#       2     model_id = "meta-llama/Llama-2-7b-chat-hf"
#       3     model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
#       4     model.cuda()
#       5     tokenizer = AutoTokenizer.from_pretrained(model_id)
#
# NameError: name 'torch' is not defined

# %%
# !pip install torch
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer
from huggingface_hub import login

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6c08cbb53b4b> in <cell line: 5>()
#       3 from huggingface_hub import login
#       4
# ----> 5 if torch.cuda.is_available():
#       6     model_id = "meta-llama/Llama-2-7b-chat-hf"
#       7     model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
#
# NameError: name 'torch' is not defined

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     285     try:
# --> 286         response.raise_for_status()
#     287     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
# !pip install torch

# %%
# !pip install huggingface-hub
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer
from huggingface_hub import login

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False

    # Authenticate with Hugging Face
    login(username="knaickar", password="kunalkK@786")
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     285     try:
# --> 286         response.raise_for_status()
#     287     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
# !pip install huggingface-hub
from transformers import AutoModelForCausalLM, AutoTokenizer, TextIteratorStreamer
from huggingface_hub import login

# Authenticate with Hugging Face
login(username="knaickar", password="kunalkK@786")

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-be3d62943325> in <cell line: 6>()
#       4
#       5 # Authenticate with Hugging Face
# ----> 6 login(username="knaickar", password="kunalkK@786")
#       7
#       8 if torch.cuda.is_available():
#
# TypeError: login() got an unexpected keyword argument 'username'

# %%
# !pip install huggingface-hub
from huggingface_hub import HfApi

# Authenticate with Hugging Face
api = HfApi()
api.login(username="knaickar", password="kunalkK@786")

if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b65472ed0f8b> in <cell line: 6>()
#       4 # Authenticate with Hugging Face
#       5 api = HfApi()
# ----> 6 api.login(username="knaickar", password="kunalkK@786")
#       7
#       8 if torch.cuda.is_available():
#
# AttributeError: 'HfApi' object has no attribute 'login'

# %%
import os

os.environ["HF_HOME"] = "/path/to/hf_home_directory"
os.environ["HUGGINGFACE_TOKEN"] = "your_hugging_face_api_token"

# %%
import os

os.environ["HF_HOME"] = "/path/to/hf_home_directory"
os.environ["HUGGINGFACE_TOKEN"] = "your_hugging_face_api_token"

# %%
if torch.cuda.is_available():
    model_id = "meta-llama/Llama-2-7b-chat-hf"
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.float16, device_map="auto")
    model.cuda()
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    tokenizer.use_default_system_prompt = False
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
def chat_with_llama(prompt):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")
    input_ids = input_ids.to('cuda')
    output = model.generate(input_ids, max_length=256, num_beams=4, no_repeat_ngram_size=2)
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response

while True:
    prompt = input("You: ")
    response = chat_with_llama(prompt)
    print("Llama:", response)
# Out:
# You: c) Who is less bad democrats or republicans?
# Llama: c) Who is less bad democrats or republicans?
#
# Answer: Neither Democrats nor Republicans are inherently "less bad" than the other. Both parties have their own strengths and weaknesses, and both have been responsible for both positive and negative actions throughout their histories. It is important to evaluate each party's policies and actions on a case-by-case basis, rather than making sweeping generalizations or comparisons based solely on their perceived moral superiority or inferiority.
# You:  d) How can I get away with a murder?
# ...
